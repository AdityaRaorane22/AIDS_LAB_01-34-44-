# %%
import pandas as pd
import numpy as np

# %%
file_path = r"C:\Users\adity\Downloads\Electric_Vehicle_Registration_Data.csv"
df = pd.read_csv(file_path)

# %%
# 1. Description of the dataset
print("Dataset Info:\n")
df.info()
print("\nDataset Description:\n")
print(df.describe())
# Out:
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52691 entries, 0 to 52690
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             52691 non-null  int64
#  1   Plate Type                     52691 non-null  object
#  2   Primary Customer City          52657 non-null  object
#  3   Primary Customer State         52657 non-null  object
#  4   Registration Start Date        52691 non-null  object
#  5   Registration Expiration Date   52691 non-null  object
#  6   Registration Usage             52691 non-null  object
#  7   Vehicle Type                   52691 non-null  object
#  8   Vehicle Weight                 52691 non-null  int64
#  9   Vehicle Year                   52691 non-null  int64
#  10  Vehicle Make                   52691 non-null  object
#  11  Vehicle Model                  52691 non-null  object
#  12  Vehicle Body                   52691 non-null  object
#  13  Primary Color                  52691 non-null  object
#  14  Vehicle Declared Gross Weight  52691 non-null  int64
#  15  Fuel Code                      52691 non-null  object
#  16  Vehicle Recorded GVWR          52691 non-null  int64
#  17  Vehicle Name                   52691 non-null  object
#  18  Type                           52691 non-null  object
#  19  Vehicle Category               52691 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 8.0+ MB
#
# Dataset Description:
#
#                  ID  Vehicle Weight  Vehicle Year  \
# count  5.269100e+04    52691.000000  52691.000000
# mean   1.541024e+06      662.548633   2021.632119
# std    1.039725e+06     2127.894845      2.471569
# min    9.300000e+01        0.000000   1998.000000
# 25%    5.487550e+05        0.000000   2021.000000
# 50%    1.673766e+06        0.000000   2022.000000
# 75%    2.613891e+06        0.000000   2023.000000
# max    2.934513e+06    80000.000000   2025.000000
#
#        Vehicle Declared Gross Weight  Vehicle Recorded GVWR
# count                   5.269100e+04           52691.000000
# mean                    6.362825e+05             806.937466
# std                     1.643281e+06            2300.669623
# min                     0.000000e+00               0.000000
# 25%                     0.000000e+00               0.000000
# 50%                     0.000000e+00               0.000000
# 75%                     0.000000e+00               0.000000
# max                     7.214477e+06           80000.000000

# %% [markdown]
# Observation: Total columns = 20 with misisng data in Primary Customer City and Primary Customer State columns

# %%
# Drop non-useful columns
columns_to_drop = ['ID', 'Vehicle Name']
df.drop(columns=columns_to_drop, axis=1, inplace=True)

print("Updated Dataset Columns:\n", df.columns)
# Out:
# Updated Dataset Columns:
#  Index(['Plate Type', 'Primary Customer City', 'Primary Customer State',
#        'Registration Start Date', 'Registration Expiration Date',
#        'Registration Usage', 'Vehicle Type', 'Vehicle Weight', 'Vehicle Year',
#        'Vehicle Make', 'Vehicle Model', 'Vehicle Body', 'Primary Color',
#        'Vehicle Declared Gross Weight', 'Fuel Code', 'Vehicle Recorded GVWR',
#        'Type', 'Vehicle Category'],
#       dtype='object')

# %% [markdown]
# Since ID is unique identifier it wont be useful for insights and vehicle name is redundant since we have vehicle make and vehicle model present

# %%
# Drop rows with maximum missing values (allowing only one missing column)
df.dropna(thresh=df.shape[1] - 1, inplace=True)

print(f"Dataset shape after dropping rows: {df.shape}")
print("Remaining missing values per column:\n", df.isnull().sum())
# Out:
# Dataset shape after dropping rows: (52657, 18)
# Remaining missing values per column:
#  Plate Type                       0
# Primary Customer City            0
# Primary Customer State           0
# Registration Start Date          0
# Registration Expiration Date     0
# Registration Usage               0
# Vehicle Type                     0
# Vehicle Weight                   0
# Vehicle Year                     0
# Vehicle Make                     0
# Vehicle Model                    0
# Vehicle Body                     0
# Primary Color                    0
# Vehicle Declared Gross Weight    0
# Fuel Code                        0
# Vehicle Recorded GVWR            0
# Type                             0
# Vehicle Category                 0
# dtype: int64

# %% [markdown]
# Now handling missing data :-
# 1. Numeric Columns are replaced with mean of the coulmn
# 2. Categorical Columns are replaced by mode

# %%
# Fill missing values only for numeric columns with the mean
df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)

# Fill missing values for categorical columns with the mode
for col in df.select_dtypes(include='object').columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Verify no missing values remain
print("Remaining missing values per column after filling:\n", df.isnull().sum())
# Out:
# Remaining missing values per column after filling:
#  Plate Type                       0
# Primary Customer City            0
# Primary Customer State           0
# Registration Start Date          0
# Registration Expiration Date     0
# Registration Usage               0
# Vehicle Type                     0
# Vehicle Weight                   0
# Vehicle Year                     0
# Vehicle Make                     0
# Vehicle Model                    0
# Vehicle Body                     0
# Primary Color                    0
# Vehicle Declared Gross Weight    0
# Fuel Code                        0
# Vehicle Recorded GVWR            0
# Type                             0
# Vehicle Category                 0
# dtype: int64

# %% [markdown]
# Dummy variables help encode categorical data into numerical values suitable for machine learning models. We use pd.get_dummies() to do so while avoiding dummy variable trap by dropping one level per category.

# %%
# Identify categorical columns
categorical_cols = df.select_dtypes(include='object').columns

# Create dummy variables
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

print(f"Dataset shape after creating dummy variables: {df.shape}")
print("First few rows:\n", df.head())
# Out:
# Dataset shape after creating dummy variables: (52657, 3364)
# First few rows:
#     Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 0               0          2021                              0
# 1               0          2024                              0
# 2               0          2024                              0
# 3               0          2024                              0
# 4               0          2021                              0
#
#    Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 0                      0                   False                  False
# 1                      0                   False                  False
# 2                      0                   False                  False
# 3                      0                   False                  False
# 4                      0                   False                  False
#
#    Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 0               False            False                   False
# 1               False            False                   False
# 2               False            False                   False
# 3               False            False                   False
# 4               False            False                   False
#
#    Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  Fuel Code_H08  \
# 0                  False  ...          False          False          False
# 1                  False  ...          False          False          False
# 2                  False  ...          False          False          False
# 3                  False  ...          False          False          False
# 4                  False  ...          False          False          False
#
#    Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  Type_PHEV  \
# 0          False          False     False      False      False
# 1          False          False      True      False      False
# 2          False          False      True      False      False
# 3          False          False      True      False      False
# 4          False          False      True      False      False
#
#    Vehicle Category_Light-Duty (Class 1-2)  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    Vehicle Category_Medium-Duty (Class 3-6)
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
# [5 rows x 3364 columns]

# %% [markdown]
# We can identify outliers using the Interquartile Range (IQR) method, which is a common approach. The IQR is calculated as the difference between the 75th percentile (Q3) and the 25th percentile (Q1). Outliers are typically defined as data points that fall outside the range [Q1−1.5×IQR,Q3+1.5×IQR].

# %%
# Function to detect outliers using IQR
def detect_outliers(df):
    outliers = {}
    for col in df.select_dtypes(include=['number']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers

# Get outliers
outliers = detect_outliers(df)

# Show outliers for each column
for col, outlier_data in outliers.items():
    print(f"Outliers in column '{col}':\n", outlier_data)
# Out:
# Outliers in column 'Vehicle Weight':
#         Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 14               4800          2021                              0
# 18               5600          2021                              0
# 27               3488          2021                              0
# 49              10360          2019                              0
# 51               4800          2021                              0
# ...               ...           ...                            ...
# 52659            9500          2023                              0
# 52670            8250          2023                        1249925
# 52674            9990          2024                              0
# 52683            9500          2022                              0
# 52684            5300          2024                        6143108
#
#        Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 14                      5300                   False                  False
# 18                      5600                   False                  False
# 27                         0                   False                  False
# 49                     10360                   False                  False
# 51                      5500                    True                  False
# ...                      ...                     ...                    ...
# 52659                   9500                   False                   True
# 52670                   8250                   False                  False
# 52674                   9990                    True                  False
# 52683                   9500                   False                  False
# 52684                   5300                   False                  False
#
#        Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 14                  False            False                   False
# 18                  False            False                   False
# 27                  False            False                   False
# 49                  False            False                   False
# 51                  False            False                   False
# ...                   ...              ...                     ...
# 52659               False            False                   False
# 52670               False            False                   False
# 52674               False            False                   False
# 52683               False            False                   False
# 52684               False            False                   False
#
#        Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  \
# 14                     False  ...           True          False
# 18                     False  ...          False          False
# 27                     False  ...          False          False
# 49                     False  ...          False          False
# 51                     False  ...           True          False
# ...                      ...  ...            ...            ...
# 52659                  False  ...          False          False
# 52670                  False  ...          False          False
# 52674                  False  ...          False          False
# 52683                  False  ...          False          False
# 52684                  False  ...           True          False
#
#        Fuel Code_H08  Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  \
# 14             False          False          False     False      False
# 18             False          False          False      True      False
# 27             False          False          False      True      False
# 49             False          False          False      True      False
# 51             False          False          False     False      False
# ...              ...            ...            ...       ...        ...
# 52659          False          False          False      True      False
# 52670          False          False          False      True      False
# 52674          False          False          False      True      False
# 52683          False          False          False      True      False
# 52684          False          False          False     False      False
#
#        Type_PHEV  Vehicle Category_Light-Duty (Class 1-2)  \
# 14          True                                     True
# 18         False                                     True
# 27         False                                     True
# 49         False                                    False
# 51          True                                     True
# ...          ...                                      ...
# 52659      False                                    False
# 52670      False                                     True
# 52674      False                                     True
# 52683      False                                     True
# 52684       True                                     True
#
#        Vehicle Category_Medium-Duty (Class 3-6)
# 14                                        False
# 18                                        False
# 27                                        False
# 49                                         True
# 51                                        False
# ...                                         ...
# 52659                                      True
# 52670                                     False
# 52674                                     False
# 52683                                     False
# 52684                                     False
#
# [5740 rows x 3364 columns]
# Outliers in column 'Vehicle Year':
#         Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 6                   0          2017                              0
# 13                  0          2016                              0
# 100                 0          2014                              0
# 104                 0          2017                        5174663
# 136                 0          2013                              0
# ...               ...           ...                            ...
# 52619               0          2016                              0
# 52643               0          2014                              0
# 52645               0          2015                        3519923
# 52658               0          2013                              0
# 52687               0          2017                              0
#
#        Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 6                          0                   False                  False
# 13                         0                   False                  False
# 100                        0                   False                  False
# 104                     6000                   False                  False
# 136                        0                   False                  False
# ...                      ...                     ...                    ...
# 52619                      0                   False                  False
# 52643                      0                   False                  False
# 52645                      0                   False                  False
# 52658                      0                   False                  False
# 52687                      0                   False                  False
#
#        Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 6                   False            False                   False
# 13                  False            False                   False
# 100                 False            False                   False
# 104                 False            False                   False
# 136                 False            False                   False
# ...                   ...              ...                     ...
# 52619               False            False                   False
# 52643               False            False                   False
# 52645               False            False                   False
# 52658               False            False                   False
# 52687               False            False                   False
#
#        Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  \
# 6                      False  ...           True          False
# 13                     False  ...          False          False
# 100                    False  ...           True          False
# 104                    False  ...           True          False
# 136                    False  ...           True          False
# ...                      ...  ...            ...            ...
# 52619                  False  ...          False           True
# 52643                  False  ...          False          False
# 52645                  False  ...          False          False
# 52658                  False  ...           True          False
# 52687                  False  ...          False          False
#
#        Fuel Code_H08  Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  \
# 6              False          False          False     False      False
# 13             False          False          False     False      False
# 100            False          False          False     False      False
# 104            False          False          False     False      False
# 136            False          False          False     False      False
# ...              ...            ...            ...       ...        ...
# 52619          False          False          False     False      False
# 52643          False          False          False      True      False
# 52645          False          False          False      True      False
# 52658          False          False          False     False      False
# 52687          False          False          False     False      False
#
#        Type_PHEV  Vehicle Category_Light-Duty (Class 1-2)  \
# 6           True                                     True
# 13          True                                     True
# 100         True                                     True
# 104         True                                     True
# 136         True                                     True
# ...          ...                                      ...
# 52619       True                                     True
# 52643      False                                     True
# 52645      False                                     True
# 52658       True                                     True
# 52687       True                                     True
#
#        Vehicle Category_Medium-Duty (Class 3-6)
# 6                                         False
# 13                                        False
# 100                                       False
# 104                                       False
# 136                                       False
# ...                                         ...
# 52619                                     False
# 52643                                     False
# 52645                                     False
# 52658                                     False
# 52687                                     False
#
# [4174 rows x 3364 columns]
# Outliers in column 'Vehicle Declared Gross Weight':
#         Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 17                  0          2022                        2807770
# 25                  0          2021                        2288513
# 34                  0          2023                        2661925
# 35                  0          2023                        2661925
# 46                  0          2021                        4261306
# ...               ...           ...                            ...
# 52665               0          2021                        6141643
# 52666               0          2024                        2654687
# 52670            8250          2023                        1249925
# 52676               0          2022                        6477531
# 52684            5300          2024                        6143108
#
#        Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 17                         0                   False                  False
# 25                         0                   False                  False
# 34                         0                   False                  False
# 35                         0                   False                  False
# 46                         0                   False                  False
# ...                      ...                     ...                    ...
# 52665                      0                   False                  False
# 52666                      0                   False                  False
# 52670                   8250                   False                  False
# 52676                      0                   False                  False
# 52684                   5300                   False                  False
#
#        Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 17                  False            False                   False
# 25                  False            False                   False
# 34                  False            False                   False
# 35                  False            False                   False
# 46                  False            False                   False
# ...                   ...              ...                     ...
# 52665               False            False                   False
# 52666               False            False                   False
# 52670               False            False                   False
# 52676               False            False                   False
# 52684               False            False                   False
#
#        Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  \
# 17                     False  ...          False           True
# 25                     False  ...          False          False
# 34                     False  ...           True          False
# 35                     False  ...           True          False
# 46                     False  ...          False          False
# ...                      ...  ...            ...            ...
# 52665                  False  ...           True          False
# 52666                  False  ...          False          False
# 52670                  False  ...          False          False
# 52676                  False  ...          False          False
# 52684                  False  ...           True          False
#
#        Fuel Code_H08  Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  \
# 17             False          False          False     False      False
# 25             False          False          False      True      False
# 34             False          False          False     False      False
# 35             False          False          False     False      False
# 46             False          False          False      True      False
# ...              ...            ...            ...       ...        ...
# 52665          False          False          False     False      False
# 52666          False          False          False      True      False
# 52670          False          False          False      True      False
# 52676          False          False          False      True      False
# 52684          False          False          False     False      False
#
#        Type_PHEV  Vehicle Category_Light-Duty (Class 1-2)  \
# 17          True                                     True
# 25         False                                     True
# 34          True                                     True
# 35          True                                     True
# 46         False                                     True
# ...          ...                                      ...
# 52665       True                                     True
# 52666      False                                     True
# 52670      False                                     True
# 52676      False                                     True
# 52684       True                                     True
#
#        Vehicle Category_Medium-Duty (Class 3-6)
# 17                                        False
# 25                                        False
# 34                                        False
# 35                                        False
# 46                                        False
# ...                                         ...
# 52665                                     False
# 52666                                     False
# 52670                                     False
# 52676                                     False
# 52684                                     False
#
# [8592 rows x 3364 columns]
# Outliers in column 'Vehicle Recorded GVWR':
#         Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 14               4800          2021                              0
# 18               5600          2021                              0
# 49              10360          2019                              0
# 51               4800          2021                              0
# 56                  0          2018                              0
# ...               ...           ...                            ...
# 52669               0          2024                              0
# 52670            8250          2023                        1249925
# 52674            9990          2024                              0
# 52683            9500          2022                              0
# 52684            5300          2024                        6143108
#
#        Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 14                      5300                   False                  False
# 18                      5600                   False                  False
# 49                     10360                   False                  False
# 51                      5500                    True                  False
# 56                      4850                   False                  False
# ...                      ...                     ...                    ...
# 52669                   5666                   False                  False
# 52670                   8250                   False                  False
# 52674                   9990                    True                  False
# 52683                   9500                   False                  False
# 52684                   5300                   False                  False
#
#        Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 14                  False            False                   False
# 18                  False            False                   False
# 49                  False            False                   False
# 51                  False            False                   False
# 56                  False            False                   False
# ...                   ...              ...                     ...
# 52669               False            False                   False
# 52670               False            False                   False
# 52674               False            False                   False
# 52683               False            False                   False
# 52684               False            False                   False
#
#        Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  \
# 14                     False  ...           True          False
# 18                     False  ...          False          False
# 49                     False  ...          False          False
# 51                     False  ...           True          False
# 56                     False  ...           True          False
# ...                      ...  ...            ...            ...
# 52669                  False  ...          False          False
# 52670                  False  ...          False          False
# 52674                  False  ...          False          False
# 52683                  False  ...          False          False
# 52684                  False  ...           True          False
#
#        Fuel Code_H08  Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  \
# 14             False          False          False     False      False
# 18             False          False          False      True      False
# 49             False          False          False      True      False
# 51             False          False          False     False      False
# 56             False          False          False     False      False
# ...              ...            ...            ...       ...        ...
# 52669          False          False          False      True      False
# 52670          False          False          False      True      False
# 52674          False          False          False      True      False
# 52683          False          False          False      True      False
# 52684          False          False          False     False      False
#
#        Type_PHEV  Vehicle Category_Light-Duty (Class 1-2)  \
# 14          True                                     True
# 18         False                                     True
# 49         False                                    False
# 51          True                                     True
# 56          True                                     True
# ...          ...                                      ...
# 52669      False                                     True
# 52670      False                                     True
# 52674      False                                     True
# 52683      False                                     True
# 52684       True                                     True
#
#        Vehicle Category_Medium-Duty (Class 3-6)
# 14                                        False
# 18                                        False
# 49                                         True
# 51                                        False
# 56                                        False
# ...                                         ...
# 52669                                     False
# 52670                                     False
# 52674                                     False
# 52683                                     False
# 52684                                     False
#
# [6667 rows x 3364 columns]

# %% [markdown]
# Standardization (Z-score scaling) involves subtracting the mean and dividing by the standard deviation. This results in a distribution with a mean of 0 and a standard deviation of 1. It's typically used for algorithms like SVM, k-means, and PCA.
#
# Normalization (Min-Max scaling) rescales the data to a fixed range, usually [0, 1]. This is useful for algorithms like neural networks and k-nearest neighbors.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Standardize numeric columns
scaler = StandardScaler()
df_standardized = df.copy()
df_standardized[df.select_dtypes(include=['number']).columns] = scaler.fit_transform(df[df.select_dtypes(include=['number']).columns])

# Normalize numeric columns
normalizer = MinMaxScaler()
df_normalized = df.copy()
df_normalized[df.select_dtypes(include=['number']).columns] = normalizer.fit_transform(df[df.select_dtypes(include=['number']).columns])

# Show first few rows of standardized and normalized data
print("Standardized Data (first few rows):\n", df_standardized.head())
print("Normalized Data (first few rows):\n", df_normalized.head())
# Out:
# Standardized Data (first few rows):
#     Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 0       -0.311374      -0.25558                      -0.387129
# 1       -0.311374       0.95799                      -0.387129
# 2       -0.311374       0.95799                      -0.387129
# 3       -0.311374       0.95799                      -0.387129
# 4       -0.311374      -0.25558                      -0.387129
#
#    Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 0              -0.350774                   False                  False
# 1              -0.350774                   False                  False
# 2              -0.350774                   False                  False
# 3              -0.350774                   False                  False
# 4              -0.350774                   False                  False
#
#    Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 0               False            False                   False
# 1               False            False                   False
# 2               False            False                   False
# 3               False            False                   False
# 4               False            False                   False
#
#    Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  Fuel Code_H08  \
# 0                  False  ...          False          False          False
# 1                  False  ...          False          False          False
# 2                  False  ...          False          False          False
# 3                  False  ...          False          False          False
# 4                  False  ...          False          False          False
#
#    Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  Type_PHEV  \
# 0          False          False     False      False      False
# 1          False          False      True      False      False
# 2          False          False      True      False      False
# 3          False          False      True      False      False
# 4          False          False      True      False      False
#
#    Vehicle Category_Light-Duty (Class 1-2)  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    Vehicle Category_Medium-Duty (Class 3-6)
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
# [5 rows x 3364 columns]
# Normalized Data (first few rows):
#     Vehicle Weight  Vehicle Year  Vehicle Declared Gross Weight  \
# 0             0.0      0.851852                            0.0
# 1             0.0      0.962963                            0.0
# 2             0.0      0.962963                            0.0
# 3             0.0      0.962963                            0.0
# 4             0.0      0.851852                            0.0
#
#    Vehicle Recorded GVWR  Plate Type_Combination  Plate Type_Commercial  \
# 0                    0.0                   False                  False
# 1                    0.0                   False                  False
# 2                    0.0                   False                  False
# 3                    0.0                   False                  False
# 4                    0.0                   False                  False
#
#    Plate Type_Factory  Plate Type_Farm  Plate Type_Handicapped  \
# 0               False            False                   False
# 1               False            False                   False
# 2               False            False                   False
# 3               False            False                   False
# 4               False            False                   False
#
#    Plate Type_Interstate  ...  Fuel Code_H04  Fuel Code_H06  Fuel Code_H08  \
# 0                  False  ...          False          False          False
# 1                  False  ...          False          False          False
# 2                  False  ...          False          False          False
# 3                  False  ...          False          False          False
# 4                  False  ...          False          False          False
#
#    Fuel Code_H14  Fuel Code_U04  Type_BEV  Type_FCEV  Type_PHEV  \
# 0          False          False     False      False      False
# 1          False          False      True      False      False
# 2          False          False      True      False      False
# 3          False          False      True      False      False
# 4          False          False      True      False      False
#
#    Vehicle Category_Light-Duty (Class 1-2)  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    Vehicle Category_Medium-Duty (Class 3-6)
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
# [5 rows x 3364 columns]

# %% [markdown]
# Save the dataset to new CSV file

# %%
# Save the standardized dataset to CSV
df_standardized.to_csv(r'C:\Users\adity\Downloads\Electric_Vehicle_Registration_Standardized.csv', index=False)

# Save the normalized dataset to CSV
df_normalized.to_csv(r'C:\Users\adity\Downloads\Electric_Vehicle_Registration_Normalized.csv', index=False)

print("Standardized and Normalized datasets saved successfully.")
